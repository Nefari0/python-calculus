# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math
from scipy.signal import find_peaks

# %%
# empirical method
x = np.linspace(-5,5,1001)
fx = x**2 * np.exp(-x**2)
dfx = np.diff(fx)/(x[1]-x[0]) # differential of fx : needs to be devided by dx

localMax = find_peaks(fx)[0]
localMin = find_peaks(-fx)[0]

print('the critical points are' + str(x[localMax]) + '' + str(x[localMin]))

plt.plot(x,fx)
plt.plot(x[0:-1],dfx)
plt.plot(x[localMax],fx[localMax],'ro')
plt.plot(x[localMin],fx[localMin],'bo')
plt.show()
# Out:
# the critical points are[-1.  1.][0.]

# %%
# deviding x = -5,5,1001 will put one int value in the center

# %%
x = sym.symbols('x')
fx = x**2 * sym.exp(-x**2)

dfx = sym.diff(fx)
critPoints = sym.solve(dfx)
critPoints
# Out:
# [-1, 0, 1]

# %%
# finding critical points for x**2 * sym.exp(-a*x**2)

a,x = sym.symbols('a,x')

baseExpr = x**2 * sym.exp(-a*x**2)

arange = np.arange(0,2.25,.25)
xrange = np.linspace(-3,3,100)

# set up figure
# first col is function itself, second col is dirivitive
fix,ax = plt.subplots(1,2)

for ai in arange:
    fx = baseExpr.subs(a,ai)
    dfx = sym.diff(fx)
    critpoints = sym.solve(dfx)
    
    
#      plotting

    ax[0].plot(xrange,sym.lambdify(x,fx)(xrange))
    ax[1].plot(xrange,sym.lambdify(x,dfx)(xrange))
    
#     test for critical points

    if 1 in critpoints:
        display(Math('\\Rightarrow %s \\text{has a critical point at x = 1}' %sym.latex(fx)))
    elif 2 in critpoints:
        display(Math('\\Rightarrow %s \\text{has a critical point at x = 2}' %sym.latex(fx)))
    else:
        display(Math('\\quad %s \\text{ has no critical points at x=1 or x=2 }' %sym.latex(fx)))
    
ax[0].set_ylim([0,2])
ax[0].set_title("function")
ax[0].plot([1,1],[0,2], '--','grey')
ax[0].plot([2,2],[0,2], '--','grey')


ax[1].set_ylim([-2,2])
ax[1].set_title("it's derivative")
ax[1].plot([1,1],[-2,2], '--','grey')
ax[1].plot([2,2],[-2,2], '--','grey')
plt.show()
# Out:
# $\displaystyle \quad x^{2} \text{ has no critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 0.25 x^{2}} \text{has a critical point at x = 2}$
# $\displaystyle \quad x^{2} e^{- 0.5 x^{2}} \text{ has no critical points at x=1 or x=2 }$
# $\displaystyle \quad x^{2} e^{- 0.75 x^{2}} \text{ has no critical points at x=1 or x=2 }$
# $\displaystyle \Rightarrow x^{2} e^{- 1.0 x^{2}} \text{has a critical point at x = 1}$
# $\displaystyle \quad x^{2} e^{- 1.25 x^{2}} \text{ has no critical points at x=1 or x=2 }$
# $\displaystyle \quad x^{2} e^{- 1.5 x^{2}} \text{ has no critical points at x=1 or x=2 }$
# $\displaystyle \quad x^{2} e^{- 1.75 x^{2}} \text{ has no critical points at x=1 or x=2 }$
# $\displaystyle \quad x^{2} e^{- 2.0 x^{2}} \text{ has no critical points at x=1 or x=2 }$

# %%
1 in [2,3,4,1]
# Out:
# True
