# %%
# notes:
# d/dx cos(x) = -sin(x)

# d/dx -sin(x) = -cos(x)

# d/dx -cos(x) = sin(x)

# d/dx sin(x) = cos(x)

# %%
import sympy as sym
from IPython.display import display,Math
import numpy as np
import matplotlib.pyplot as plt
import sympy.plotting.plot as symplot

# %%
q = sym.symbols('q')

print(sym.diff( sym.cos(q) ))
print(sym.diff( sym.sin(q) ))
# Out:
# -sin(q)
# cos(q)

# %%
f = sym.cos(q)

for i in range(0,8):
    display(Math('\\frac{d}{dx}%s = %s' \
                 %(sym.latex(f),sym.latex(sym.diff(f)))))
    f = sym.diff(f)
# Out:
# $\displaystyle \frac{d}{dx}\cos{\left(q \right)} = - \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \sin{\left(q \right)} = - \cos{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \cos{\left(q \right)} = \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}\sin{\left(q \right)} = \cos{\left(q \right)}$
# $\displaystyle \frac{d}{dx}\cos{\left(q \right)} = - \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \sin{\left(q \right)} = - \cos{\left(q \right)}$
# $\displaystyle \frac{d}{dx}- \cos{\left(q \right)} = \sin{\left(q \right)}$
# $\displaystyle \frac{d}{dx}\sin{\left(q \right)} = \cos{\left(q \right)}$

# %%
# testing math and computation funtions
import sympy.plotting.plot as symplot

f = sym.cos(q)



for i in range(0,4):
    
    if i == 0:
        p = symplot(f,label=sym.latex(f),show=False,line_color=(i/5,i/3,i/5))
#         p = symplot(f,show=False,label=sym.latex(f))
    else:
        p.extend( symplot(f,label=sym.latex(f),show=False,line_color=(i/5,i/3,i/5)) )
    f = sym.diff(f)
p.legend = True
p.xlim = [-3,3]
p.show()

# %%
# prototype
# f_a = cos(x + sin(x)) + a

x = sym.symbols('x')

for a in range(0,4):
    if a == 0:
        f = sym.cos(x +sym.sin(x)) + a
        p = symplot(f,show=False)
        pdf = symplot(sym.diff(f),show=False)
    else:
        f = sym.cos(x +sym.sin(x)) + a
        p.extend( symplot(f,label=sym.latex(f),show=False) )
        pdf.extend( symplot(sym.diff(f),show=False))

# p.xlim = [-5,5]
pdf.xlim = [-5,5]
p.show()
pdf.show()

# %%
# plotting derivatives of trig functions
x,a = sym.symbols('x,a')

f = sym.cos( x + sym.sin(x)) + a
colors = 'brkm'

# ----the functions----

for ai in range(0,4):
    if ai==0:
        p = symplot(f.subs(a,ai),show=False,label='a=' + str(ai),line_color=colors[0])
    else:
        p.extend( symplot(f.subs(a,ai),show=False,label='a=' + str(ai),line_color=colors[ai]))

p.title = "The functions"
p.legend = True
p.show()

# ----derivatives of the functions----

for ai in range(0,4):
    if ai==0:
        p = symplot(sym.diff(f.subs(a,ai)),show=False,label='a=' + str(ai),line_color=colors[0])
    else:
        p.extend( symplot(sym.diff(f.subs(a,ai)),show=False,label='a=' + str(ai),line_color=colors[ai]))

p.title = "Their derivatives"
p.legend = True
p.show()

# %%
# experimental
# these are the default non circular parameters from otvinta
u = sym.symbols('u')
# uu = np.linspace(-3,3,200)
uu = np.linspace(0,2*np.pi,200)

# non_circ = 4 + sym.cos(3*u)+sym.sin(2*u) # original function/unmodified
non_circ = sym.cos(3*u)+sym.sin(2*u) # modified function
np_non_circ = np.cos(3*pi)+np.sin(2*pi) # numpy version of above code
dv_non_circ = sym.diff(non_circ)

noncirc = sym.lambdify(u,non_circ)(uu)
dv_noncirc = sym.lambdify(u,dv_non_circ)(uu) # for use in merging modules


p = symplot(non_circ,label=sym.latex(non_circ),show=False,line_color=(i/5,i/3,i/5))

p.extend( symplot(dv_non_circ,label=sym.latex(dv_non_circ),show=False,line_color=('blue')) )

p.legend = True
p.xlim = [-3,3]
p.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-878ae1fcbde7> in <module>
#      20 p.legend = True
#      21 p.xlim = [-3,3]
# ---> 22 p.show()
#
# ~\anaconda3\lib\site-packages\sympy\plotting\plot.py in show(self)
#     212             self._backend.close()
#     213         self._backend = self.backend(self)
# --> 214         self._backend.show()
#     215
#     216     def save(self, path):
#
# ~\anaconda3\lib\site-packages\sympy\plotting\plot.py in show(self)
#    1324
#    1325     def show(self):
# -> 1326         self.process_series()
#    1327         #TODO after fixing https://github.com/ipython/ipython/issues/1255
#    1328         # you can uncomment the next line and remove the pyplot.show() call
#
# ~\anaconda3\lib\site-packages\sympy\plotting\plot.py in process_series(self)
#    1321             if isinstance(self.parent, PlotGrid):
# ...

# %%
# experimental
pi = np.linspace(0,2*np.pi,200)
# print(dv_noncirc)
# plt.plot(uu,dv_noncirc,label='derivative')
# plt.plot(uu,noncirc,label='function')
# plt.plot(noncirc*np.cos(pi),noncirc*np.sin(pi))
for i in range(len(pi)):
    plt.plot(np_non_circ[i]*np.cos(uu[i]),np_non_circ[i]*np.sin(uu[i]),'ro')
#     plt.plot(funci[i]*np.cos(xx[i]),funci[i]*np.sin(xx[i]),'ro')

# plt.legend()
plt.axis('square')
# Out:
# (-1.330730184910986,
#  2.2238897957167154,
#  -1.7775587910017712,
#  1.7770611896259303)

# %%
# experimental
# plt.polar(uu,dv_noncirc)
plt.polar(uu,noncirc)

# %%
# experimental
plt.polar(uu,dv_noncirc)
plt.polar(uu,noncirc)
display(dv_non_circ)
display(non_circ)
# Out:
# -3*sin(3*u) + 2*cos(2*u)
# sin(2*u) + cos(3*u)
